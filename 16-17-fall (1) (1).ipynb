# %%
>>> import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
import seaborn as sns # a visualization library from matplotlib
from math import sin, cos, sqrt, atan2, radians
import json
import pprint
import ast

# %%
Course_df = pd.read_excel(r"/Users/artun/Desktop/ens491:burak_kocuk/16-17-fall-course.xlsx") #course list
TA_df =pd.read_excel(r"/Users/artun/Desktop/ens491:burak_kocuk/16-17-fall-ta.xlsx") # TA preference list
students_df = pd.read_excel("/Users/artun/Downloads/2015-2019 UG Courses.xlsx")

# %%
course_n_rows,course_n_columns = Course_df.shape  # get the shape of dataframe
print("Shape of course dataframe is")
print("number of rows: {}, number of columns: {}".format(course_n_rows, course_n_columns))
# Out:
# Shape of course dataframe is
# number of rows: 103, number of columns: 9

# %%
is_2016fall = students_df['Semester'] == '2016-1'
fall_2016df = students_df[is_2016fall]
fall_2016df = fall_2016df.reset_index()
fall_2016df.head(65)
student_n_rows,student_n_columns = fall_2016df.shape

# %%
n_rows, n_columns = TA_df.shape  # get the shape of dataframe
print("Shape of TA dataframe is")
print("number of rows: {}, number of columns: {}".format(n_rows, n_columns))
# Out:
# Shape of TA dataframe is
# number of rows: 315, number of columns: 11

# %%
print("315 TA's assigned to FENS courses during fall semester of 2014/2015")
# Out:
# 315 TA's assigned to FENS courses during fall semester of 2014/2015

# %% [markdown]
# # Brief preview of both TA and Course preference lists¶

# %%
Course_df.head(course_n_rows)
# Out:
#          CRN             Name Section                           Title  \
# 0        NaN              NaN     NaN                             NaN
# 1    10367.0          BIO 306       0                    Microbiology
# 2    10369.0          BIO 308       0                Plant Physiology
# 3    10373.0          BIO 321       0                  Biochemistry I
# 4    10375.0          BIO 332       0                    Cell Biology
# 5    10371.0          BIO 407       0      Multicellular Organization
# 6    10377.0          BIO 445       0      Plant Tissue Culture Tech.
# 7    10372.0          BIO 447       0                  Plant Breeding
# 8    10380.0          BIO 452       0                      Immunology
# 9    10387.0         CHEM 301       0             Inorganic Chemistry
# 10   10389.0         CHEM 405       0                Electrochemistry
# 11   10916.0           CS 201       0       Introduction to Computing
# 12   10933.0           CS 204       0            Advanced Programming
# 13   10391.0           CS 300       0                 Data Structures
# 14   10393.0           CS 302       0     Formal Lang&Automata Theory
# 15   10394.0           CS 303       0                           Logic
# 16   10402.0           CS 307       0               Operating Systems
# 17   10404.0           CS 400       0       Logic in Computer Science
# 18   10406.0           CS 402       0                 Compiler Design
# 19   10407.0           CS 405       0               Computer Graphics
# 20   10409.0           CS 408       0               Computer Networks
# 21   10419.0           EE 303       0      Analog Integrated Circuits
# 22   10421.0           EE 307       0      Semiconductor Phy.&Devices
# 23   10423.0           EE 311       0  Int.to Signal Pro.&Infor.Syst.
# 24   10425.0           EE 313       0  Intro.to Communication Systems
# 25   10427.0           EE 401       0           VLSI Systems Design I
# 26   10429.0           EE 403       0                 Optoelectronics
# 27   10431.0           EE 407       0     Microelectronic Fabrication
# 28   10434.0           EE 409       0                      Microwaves
# 29   10436.0           EE 413       0         Wireless Communications
# ..       ...              ...     ...                             ...
# 73   10849.0         MATH 306       0           Statistical Modelling
# 74   10537.0         MATH 317       0        Elementary Number Theory
# 75   10538.0         MATH 414       0  Finite Fields and Applications
# 76   10544.0           ME 301       0            Mechanical Systems I
# 77   10547.0           ME 303       0           Control System Design
# 78   10551.0           ME 304       0          Motion Control Systems
# 79   10554.0           ME 307       0                  Fluid Dynamics
# 80   10556.0           ME 308       0              Industrial Control
# 81   10559.0           ME 402       0                      Plasmonics
# 82   10561.0           ME 403       0        Introduction to Robotics
# 83   11156.0           ME 405       0           Mechanical Vibrations
# 84   10565.0           ME 407       0                Embedded Systems
# 85   11247.0           ME 409       0     Foundations Of Microsystems
# 86   11252.0           ME 435       0  Scaling In Engineering Systems
# 87   10568.0           ME 480       0       Spc.Top.in Mechatronics I
# 88   10671.0          MJC 100       0       Majors:informative Course
# 89   10738.0           NS 101       A             Science of Nature I
# 90   10751.0           NS 102       A            Science Of Nature Ii
# 91   10571.0           NS 201       0                Discovering Life
# 92   10573.0           NS 206       0            Inside The Milky Way
# 93   11154.0           NS 207       0               Organic Chemistry
# 94   10574.0           NS 213       0       Basic Concepts of Physics
# 95   10575.0           NS 222       0   Planetary Sys.&Extraslr Plane
# 96   20000.0          PHD 100       1                 Qualifying Exam
# 97   10576.0         PHYS 303       0             Quantum Mechanics I
# 98   10578.0         PHYS 401       0             Classical Mechanics
# 99   10531.0         PHYS 412       0           Statistical Mechanics
# 100  11144.0         PHYS 438       0  Phase Trans.&Renorm.-Group Th.
# 101  10760.0         PROJ 102       0                  Project Course
# 102  11111.0  TLL 101 TLL 101       0                               0
#
#         Preferred  Hours Assigned  Hours Requested  \
# 0    Grad Program             NaN              NaN
# 1             NaN            15.0             15.0
# 2             NaN            15.0             15.0
# 3             NaN            25.0             20.0
# 4             NaN            30.0             20.0
# 5             NaN             5.0              5.0
# 6             NaN            10.0              5.0
# 7             NaN             0.0              5.0
# 8             NaN            10.0             10.0
# 9             NaN            25.0             15.0
# 10            NaN             5.0              5.0
# 11            NaN           210.0            152.0
# 12            NaN            70.0             43.0
# 13            NaN            30.0             45.0
# 14            NaN            20.0             15.0
# 15            NaN            60.0             87.0
# 16            NaN            20.0             35.0
# 17            NaN            10.0              5.0
# 18            NaN            10.0              5.0
# 19            NaN            10.0             15.0
# 20            NaN            40.0             50.0
# 21            NaN            20.0             20.0
# 22            NaN            10.0             10.0
# 23            NaN            10.0             25.0
# 24            NaN            10.0             15.0
# 25            NaN            10.0             15.0
# 26            NaN             5.0              5.0
# 27            NaN            10.0              5.0
# 28            NaN            10.0             10.0
# 29            NaN             5.0              5.0
# ..            ...             ...              ...
# 73            NaN            50.0            100.0
# 74            NaN            10.0              5.0
# 75            NaN             0.0              5.0
# 76            NaN            40.0             45.0
# 77            NaN            30.0             40.0
# 78            NaN             0.0             25.0
# 79            NaN            30.0             38.0
# 80            NaN            30.0             30.0
# 81            NaN            20.0             10.0
# 82            NaN            40.0             35.0
# 83             ME            10.0             15.0
# 84            NaN            20.0             20.0
# 85             ME            20.0             10.0
# 86             ME            10.0             10.0
# 87            NaN             0.0             15.0
# 88             CS            30.0             30.0
# 89            NaN           240.0            205.0
# 90            NaN           185.0             54.0
# 91            NaN            25.0             30.0
# 92            NaN            20.0             30.0
# 93            NaN            40.0             35.0
# 94            NaN            10.0             25.0
# 95            NaN            10.0             20.0
# 96              0             0.0              5.0
# 97            NaN             0.0             10.0
# 98            NaN             0.0              5.0
# 99            NaN             0.0              5.0
# 100           NaN             0.0             10.0
# 101            CS            40.0             20.0
# 102            CS             0.0             10.0
#
#                              Requesting Teaching Grads  \
# 0                                                  NaN
# 1    1-Yunus Akkoc ( 65757 ) (10 / 10)\n2-Raheela R...
# 2    1-Cevza Esin Tunc ( 65674 ) (10 / 10)\n1-Rahee...
# 3    2-Yunus Akkoc ( 65757 ) (10 / 10)\n3-Melike Ge...
# 4    2-Nazife Tolay ( 65329 ) (10 / 10)\n2-Melike G...
# 5    3-Burcin Ustbas ( 65608 ) (10 / 10)\n4-Nazife ...
# 6    1-Melike Cokol Cakmak ( 65683 ) (10 / 10)\n1-O...
# 7                  1-Babar Hussain ( 65423 ) (10 / 10)
# 8    1-Ronay Cetin ( 65771 ) (20 / 10)\n2-Cevza Esi...
# 9    1-Zahra Goharibajestani ( 65494 ) (20 / 20)\n3...
# 10   1-Esaam Jamil ( 65367 ) (10 / 10)\n1-Mahdieh S...
# 11   1-Gizem Gezici ( 65246 ) (10 / 10)\n1-Yasin Fi...
# 12   1-Stefan Rabiger ( 65504 ) (20 / 20)\n1-Mahsa ...
# 13   1-Hanefi Mercan ( 65678 ) (10 / 10)\n1-Baran U...
# 14   1-Figen Beken Fikri ( 65512 ) (20 / 20)\n2-Giz...
# 15   1-Gunet Eroglu ( 65300 ) (20 / 20)\n1-Mehmet D...
# 16   1-Tolun Tosun ( 65422 ) (20 / 20)\n2-Arsalan J...
# 17   2-Yusuf Izmirlioglu ( 65382 ) (10 / 10)\n4-Omi...
# 18   1-Sertac Karahoda ( 65254 ) (10 / 10)\n4-Gokha...
# 19   1-Gokhan Gokturk ( 65519 ) (10 / 10)\n2-Baran ...
# 20   1-Omer Mert Candan ( 65417 ) (10 / 10)\n1-Best...
# 21   1-Shahbaz Abbasi ( 65383 ) (10 / 10)\n1-Abdurr...
# 22   3-Asuman Kolbasi ( 65638 ) (0 / 10)\n4-Ridvan ...
# 23   2-Muhammed Burak Alver ( 65437 ) (10 / 10)\n2-...
# 24   1-Mikail Yilan ( 65287 ) (10 / 10)\n2-Amin Far...
# 25   1-Ahmet Can Mert ( 65476 ) (10 / 10)\n1-Onur Z...
# 26   1-Baturay Ozgurun ( 65309 ) (20 / 20)\n4-Moham...
# 27   3-Taylan Erol ( 65662 ) (0 / 20)\n3-Onur Zirhl...
# 28   1-Haq Nawaz ( 65610 ) (10 / 10)\n2-Eesa Rahimi...
# 29   2-Mikail Yilan ( 65287 ) (10 / 10)\n3-Artrim K...
# ..                                                 ...
# 73                   4-Tolun Tosun ( 65422 ) (20 / 20)
# 74   1-Seyyed Hamed Mousavi ( 65441 ) (20 / 20)\n2-...
# 75                  1-Burcin Gunes ( 65686 ) (20 / 20)
# 76   1-Erdem Gorgun ( 65657 ) (10 / 10)\n2-Yaser Mo...
# 77   1-Diyar Khalis Bilal ( 65323 ) (20 / 20)\n1-Va...
# 78   1-Akhtar Rasool ( 65752 ) (10 / 10)\n2-Gokhan ...
# 79   1-Morteza Ghorbani ( 65278 ) (10 / 10)\n1-Ali ...
# 80   1-Beste Bahceci ( 65340 ) (10 / 10)\n2-Koray E...
# 81   1-Eesa Rahimi ( 65500 ) (10 / 10)\n1-Muhammed ...
# 82   1-Ata Otaran ( 65355 ) (10 / 10)\n3-Wisdom Chu...
# 83                  4-Sahl Sadeghi ( 65527 ) (10 / 10)
# 84   1-Ozdemir Can Kara ( 65255 ) (10 / 10)\n2-Muba...
# 85   1-Ozdemir Can Kara ( 65255 ) (10 / 10)\n2-Muba...
# 86   1-Ozdemir Can Kara ( 65255 ) (10 / 10)\n2-Muba...
# 87          1-Hande Karamahmutoglu ( 65347 ) (10 / 10)
# 88   1-Muhammed Kocak ( 65513 ) (20 / 20)\n1-Ozlem ...
# 89   1-Firas Abdul Ghani ( 65515 ) (10 / 10)\n1-Asu...
# 90   1-Rokhsareh Bakhtiari ( 65763 ) (10 / 10)\n1-B...
# 91   1-Melike Gezen ( 65721 ) (10 / 10)\n1-Nazife T...
# 92   2-Hammad Munawar ( 65499 ) (0 / 20)\n2-Taylan ...
# 93   1-Ece Arici ( 65348 ) (10 / 10)\n1-Emre Burak ...
# 94   1-Ozan Toyran ( 65606 ) (10 / 10)\n2-Bora Atal...
# 95   1-Ali Arda Gencali ( 65526 ) (20 / 20)\n1-Deni...
# 96   1-Ali Arda Gencali ( 65526 ) (20 / 20)\n1-Deni...
# 97                   2-Firat Diker ( 65724 ) (20 / 20)
# 98               2-Artrim Kjamilji ( 65374 ) (10 / 10)
# 99                   2-Tolga Caglar ( 65414 ) (0 / 20)
# 100                  1-Tolga Caglar ( 65414 ) (0 / 20)
# 101  1-Sanaz Abbasi ( 65772 ) (10 / 10)\n1-Seyedeh ...
# 102  1-Sanaz Abbasi ( 65772 ) (10 / 10)\n1-Seyedeh ...
#
#                                Assigned Teaching Grads
# 0                                                  NaN
# 1    Yunus Akkoc (65757, BIO, 10 hours)\nBiran Musu...
# 2    Cevza Esin Tunc (65674, BIO, 10 hours)\nRaheel...
# 3    Sevde Nur Karatas (65640, BIO, 20 hours)\nBahr...
# 4    Ronay Cetin (65771, BIO, 10 hours)\nLolai Ikro...
# 5          Halise Busra Cagirici (65299, BIO, 5 hours)
# 6           Melike Cokol Cakmak (65683, BIO, 10 hours)
# 7                                                 None
# 8                   Ronay Cetin (65771, BIO, 10 hours)
# 9    Zahra Goharibajestani (65494, MAT, 20 hours)\n...
# 10        Sina Abdolhosseinzadeh (65378, MAT, 5 hours)
# 11   Gizem Gezici (65246, CS, 10 hours)\nYasin Find...
# 12   Stefan Rabiger (65504, CS, 20 hours)\nMustafa ...
# 13   Hanefi Mercan (65678, CS, 10 hours)\nMehmet Ca...
# 14             Figen Beken Fikri (65512, CS, 20 hours)
# 15   Mehmet Denizhan Erdem (65558, CS, 20 hours)\nC...
# 16                   Tolun Tosun (65422, CS, 20 hours)
# 17                  Ezgi Demirel (65251, CS, 10 hours)
# 18               Sertac Karahoda (65254, CS, 10 hours)
# 19                Gokhan Gokturk (65519, CS, 10 hours)
# 20   Omer Mert Candan (65417, CS, 10 hours)\nEmir A...
# 21   Abdurrahman Burak (65598, EE, 10 hours)\nCan C...
# 22               Emre Can Durmaz (65540, EE, 10 hours)
# 23      Mehdi Salehi Heydar Abad (65419, EE, 10 hours)
# 24   Muhammad Sohaib Sohaib Amjad (65798, EE, 10 ho...
# 25                Ahmet Can Mert (65476, EE, 10 hours)
# 26   Behzad Sardari Ghojehbeiglou (65679, EE, 5 hours)
# 27                Elif Gul Arsoy (65509, EE, 10 hours)
# 28                     Haq Nawaz (65610, EE, 10 hours)
# 29              Rupak Bardhan Roy (65266, EE, 5 hours)
# ..                                                 ...
# 73   Amin Farajzadeh (65773, EE, 20 hours)\nDidem A...
# 74           Emine Tugba Yesin (65695, MATH, 10 hours)
# 75                                                None
# 76   Ahmet Selim Pehlivan (65589, ME, 10 hours)\nEr...
# 77   Vahid Tavakol Aghaei (65427, ME, 10 hours)\nSa...
# 78                                                None
# 79   Morteza Ghorbani (65278, ME, 10 hours)\nAli Mo...
# 80   Beste Bahceci (65340, ME, 10 hours)\nMustafa Y...
# 81   Eesa Rahimi (65500, ME, 10 hours)\nMuhammed Al...
# 82   Gokay Coruhlu (65401, ME, 10 hours)\nWisdom Ch...
# 83                 Ahmet sahinoz (65534, ME, 10 hours)
# 84   Ozdemir Can Kara (65255, ME, 10 hours)\nOytun ...
# 85   Sarp Akgonul (65597, ME, 10 hours)\nAbdolali K...
# 86          Hande Karamahmutoglu (65347, ME, 10 hours)
# 87                                                None
# 88   Ozlem Yedier (65560, BIO, 10 hours)\nCevriye P...
# 89   Didem Ozkazanc (65272, BIO, 10 hours)\nGoksin ...
# 90   Adnan Tasdemir (65557, MAT, 10 hours)\nAhmet M...
# 91   Nazife Tolay (65329, BIO, 10 hours)\nMelike Ge...
# 92            Ali Arda Gencali (65526, PHYS, 20 hours)
# 93   Ece Arici (65348, MAT, 10 hours)\nBegum Yarar ...
# 94           Murat Gokhan Eskin (65655, MAT, 10 hours)
# 95          Deniz Gulfem Ozturk (65544, BIO, 10 hours)
# 96                                                None
# 97                                                None
# 98                                                None
# 99                                                None
# 100                                               None
# 101  Ali Nadernezhad (65292, MAT, 10 hours)\nSeyede...
# 102                                               None
#
# [103 rows x 9 columns]

# %%
TA_df.head()
# Out:
#    Student ID                           Name Degree Program  Hours Assigned  \
# 0       19928         Abba Ibrahim \nRamadan    PHD    MATH              20
# 1       18282  Abdolali \nKhalili Sadaghiani    PHD      ME              20
# 2       14277            Abdurrahman \nBurak     MS      EE              10
# 3       20205               Adnan \nTaşdemir    PHD     MAT              10
# 4       21965         Ahmad Reza\nMotezakker     MS      ME              10
#
#    Hours Requested                                  Requested Courses  \
# 0               20  1- MATH 201 (190 / 125)\n2- MATH 301 (20 / 15)...
# 1               20  1- ENS 209 (120 / 100)\n2- ME 307 (30 / 38)\n3...
# 2               10  1- EE 303 (20 / 20)\n2- EE 480 (0 / 5)\n3- ENS...
# 3               10                                                NaN
# 4               10  1- ENS 204 (50 / 75)\n2- MATH 101 (325 / 188)\...
#
#   Assigned Course 1    CRN 1 Assigned Course 2    CRN 2
# 0          MATH 201  10945.0               NaN      NaN
# 1            ME 307  10554.0          \nME 409  11247.0
# 2            EE 303  10419.0               NaN      NaN
# 3            NS 102  10751.0               NaN      NaN
# 4           ENS 204  10888.0               NaN      NaN

# %% [markdown]
# # Data types for TA & Courses dataframes¶

# %%
TA_df.dtypes
# Out:
# Student ID             int64
# Name                  object
# Degree                object
# Program               object
# Hours Assigned         int64
# Hours Requested        int64
# Requested Courses     object
# Assigned Course 1     object
# CRN 1                float64
# Assigned Course 2     object
# CRN 2                float64
# dtype: object

# %%
Course_df.dtypes
# Out:
# CRN                          float64
# Name                          object
# Section                       object
# Title                         object
# Preferred                     object
# Hours Assigned               float64
# Hours Requested              float64
# Requesting Teaching Grads     object
# Assigned Teaching Grads       object
# dtype: object

# %% [markdown]
# # Dealing with Dirty Data

# %%
# TA dataframe first
TA_df = TA_df.fillna(0) # NaN values are cumbersome values. Change all to 0
TA_df['CRN 1'] = TA_df['CRN 1'].astype('int64') # CRN values are actually integer values. However , they are float in the file
# Change the CRN 1 column value type to int as expected
TA_df['CRN 2'] = TA_df['CRN 2'].astype('int64')
#Change the CRN 2 column value type to int as expected
TA_df['Name'] = TA_df['Name'].replace('\n',' ', regex=True)
TA_df['Assigned Course 2'] = TA_df['Assigned Course 2'].replace('\n',' ', regex=True)

# %%
TA_df.head()
# Out:
#    Student ID                          Name Degree Program  Hours Assigned  \
# 0       19928         Abba Ibrahim  Ramadan    PHD    MATH              20
# 1       18282  Abdolali  Khalili Sadaghiani    PHD      ME              20
# 2       14277            Abdurrahman  Burak     MS      EE              10
# 3       20205               Adnan  Taşdemir    PHD     MAT              10
# 4       21965         Ahmad Reza Motezakker     MS      ME              10
#
#    Hours Requested                                  Requested Courses  \
# 0               20  1- MATH 201 (190 / 125)\n2- MATH 301 (20 / 15)...
# 1               20  1- ENS 209 (120 / 100)\n2- ME 307 (30 / 38)\n3...
# 2               10  1- EE 303 (20 / 20)\n2- EE 480 (0 / 5)\n3- ENS...
# 3               10                                                  0
# 4               10  1- ENS 204 (50 / 75)\n2- MATH 101 (325 / 188)\...
#
#   Assigned Course 1  CRN 1 Assigned Course 2  CRN 2
# 0          MATH 201  10945                 0      0
# 1            ME 307  10554            ME 409  11247
# 2            EE 303  10419                 0      0
# 3            NS 102  10751                 0      0
# 4           ENS 204  10888                 0      0

# %%
# Course dataframes turn
Course_df = Course_df.fillna(0) # replace all NaN values with 0
Course_df = Course_df.drop(Course_df.index[0])
Course_df['CRN'] = Course_df['CRN'].astype('int64')
Course_df['Hours Assigned'] = Course_df['Hours Assigned'].astype('int64')
Course_df['Hours Requested'] = Course_df['Hours Requested'].astype('int64')
Course_df.head()
# Out:
#      CRN     Name Section                       Title Preferred  \
# 1  10367  BIO 306       0                Microbiology         0
# 2  10369  BIO 308       0            Plant Physiology         0
# 3  10373  BIO 321       0              Biochemistry I         0
# 4  10375  BIO 332       0                Cell Biology         0
# 5  10371  BIO 407       0  Multicellular Organization         0
#
#    Hours Assigned  Hours Requested  \
# 1              15               15
# 2              15               15
# 3              25               20
# 4              30               20
# 5               5                5
#
#                            Requesting Teaching Grads  \
# 1  1-Yunus Akkoc ( 65757 ) (10 / 10)\n2-Raheela R...
# 2  1-Cevza Esin Tunc ( 65674 ) (10 / 10)\n1-Rahee...
# 3  2-Yunus Akkoc ( 65757 ) (10 / 10)\n3-Melike Ge...
# 4  2-Nazife Tolay ( 65329 ) (10 / 10)\n2-Melike G...
# 5  3-Burcin Ustbas ( 65608 ) (10 / 10)\n4-Nazife ...
#
#                              Assigned Teaching Grads
# 1  Yunus Akkoc (65757, BIO, 10 hours)\nBiran Musu...
# 2  Cevza Esin Tunc (65674, BIO, 10 hours)\nRaheel...
# 3  Sevde Nur Karatas (65640, BIO, 20 hours)\nBahr...
# 4  Ronay Cetin (65771, BIO, 10 hours)\nLolai Ikro...
# 5        Halise Busra Cagirici (65299, BIO, 5 hours)

# %% [markdown]
# ## How many TA's requested for each course ?

# %%
for courses in range(1,course_n_rows) :
    data = Course_df.at[courses,'Requesting Teaching Grads'].splitlines() 
    print(Course_df.at[courses,'Name'] , "requested" ,len(data),"TA's")
# Out:
# BIO 306 requested 3 TA's
# BIO 308 requested 5 TA's
# BIO 321 requested 4 TA's
# BIO 332 requested 6 TA's
# BIO 407 requested 2 TA's
# BIO 445 requested 5 TA's
# BIO 447 requested 1 TA's
# BIO 452 requested 5 TA's
# CHEM 301 requested 4 TA's
# CHEM 405 requested 11 TA's
# CS 201 requested 23 TA's
# CS 204 requested 14 TA's
# CS 300 requested 14 TA's
# CS 302 requested 4 TA's
# CS 303 requested 6 TA's
# CS 307 requested 8 TA's
# CS 400 requested 2 TA's
# CS 402 requested 2 TA's
# CS 405 requested 3 TA's
# CS 408 requested 6 TA's
# EE 303 requested 4 TA's
# EE 307 requested 2 TA's
# EE 311 requested 5 TA's
# EE 313 requested 4 TA's
# EE 401 requested 2 TA's
# EE 403 requested 2 TA's
# EE 407 requested 2 TA's
# EE 409 requested 2 TA's
# EE 413 requested 2 TA's
# EE 414 requested 2 TA's
# EE 417 requested 1 TA's
# EE 473 requested 4 TA's
# EE 480 requested 3 TA's
# ELAE 1 requested 3 TA's
# ENS 202 requested 3 TA's
# ENS 203 requested 8 TA's
# ENS 204 requested 9 TA's
# ENS 205 requested 30 TA's
# ENS 208 requested 20 TA's
# ENS 209 requested 22 TA's
# ENS 211 requested 10 TA's
# ENS 491 requested 4 TA's
# GR 555 E requested 8 TA's
# IE 301 requested 14 TA's
# IE 302 requested 11 TA's
# IE 303 requested 25 TA's
# IE 304 requested 8 TA's
# IE 305 requested 8 TA's
# IE 309 requested 15 TA's
# IE 401 requested 14 TA's
# IE 402 requested 6 TA's
# IE 403 requested 6 TA's
# IE 405 requested 15 TA's
# IE 407 requested 4 TA's
# IE 408 requested 1 TA's
# IE 409 requested 8 TA's
# IE 413 requested 5 TA's
# IE 430 requested 8 TA's
# IE 454 requested 1 TA's
# IE 471 requested 1 TA's
# IE 472 requested 4 TA's
# MAT 305 requested 13 TA's
# MAT 312 requested 13 TA's
# MAT 314 requested 9 TA's
# MAT 404 requested 6 TA's
# MAT 408 requested 8 TA's
# MAT 511 requested 8 TA's
# MATH 101 requested 88 TA's
# MATH 102 requested 52 TA's
# MATH 201 requested 33 TA's
# MATH 203 requested 19 TA's
# MATH 301 requested 6 TA's
# MATH 306 requested 1 TA's
# MATH 317 requested 5 TA's
# MATH 414 requested 1 TA's
# ME 301 requested 8 TA's
# ME 303 requested 11 TA's
# ME 304 requested 2 TA's
# ME 307 requested 8 TA's
# ME 308 requested 4 TA's
# ME 402 requested 3 TA's
# ME 403 requested 3 TA's
# ME 405 requested 1 TA's
# ME 407 requested 3 TA's
# ME 409 requested 3 TA's
# ME 435 requested 3 TA's
# ME 480 requested 1 TA's
# MJC 100 requested 7 TA's
# NS 101 requested 22 TA's
# NS 102 requested 19 TA's
# NS 201 requested 11 TA's
# NS 206 requested 5 TA's
# NS 207 requested 9 TA's
# NS 213 requested 4 TA's
# NS 222 requested 4 TA's
# PHD 100 requested 4 TA's
# PHYS 303 requested 1 TA's
# PHYS 401 requested 1 TA's
# PHYS 412 requested 1 TA's
# PHYS 438 requested 1 TA's
# PROJ 102 requested 30 TA's
# TLL 101 TLL 101 requested 30 TA's

# %% [markdown]
# ## How many TA's assigned to each course ?

# %%
for TA in range(1,course_n_rows) :
    if Course_df.at[TA,'Assigned Teaching Grads'] != "None" :
        data = Course_df.at[TA,'Assigned Teaching Grads'].splitlines()
        print(Course_df.at[TA,'Name'] , "assigned" ,len(data),"TA's")
    else :
        print(Course_df.at[TA,'Name'] , "assigned" , 0,"TA's")
# Out:
# BIO 306 assigned 2 TA's
# BIO 308 assigned 2 TA's
# BIO 321 assigned 2 TA's
# BIO 332 assigned 3 TA's
# BIO 407 assigned 1 TA's
# BIO 445 assigned 1 TA's
# BIO 447 assigned 0 TA's
# BIO 452 assigned 1 TA's
# CHEM 301 assigned 2 TA's
# CHEM 405 assigned 1 TA's
# CS 201 assigned 15 TA's
# CS 204 assigned 4 TA's
# CS 300 assigned 2 TA's
# CS 302 assigned 1 TA's
# CS 303 assigned 4 TA's
# CS 307 assigned 1 TA's
# CS 400 assigned 1 TA's
# CS 402 assigned 1 TA's
# CS 405 assigned 1 TA's
# CS 408 assigned 3 TA's
# EE 303 assigned 2 TA's
# EE 307 assigned 1 TA's
# EE 311 assigned 1 TA's
# EE 313 assigned 1 TA's
# EE 401 assigned 1 TA's
# EE 403 assigned 1 TA's
# EE 407 assigned 1 TA's
# EE 409 assigned 1 TA's
# EE 413 assigned 1 TA's
# EE 414 assigned 1 TA's
# EE 417 assigned 1 TA's
# EE 473 assigned 0 TA's
# EE 480 assigned 0 TA's
# ELAE 1 assigned 0 TA's
# ENS 202 assigned 1 TA's
# ENS 203 assigned 4 TA's
# ENS 204 assigned 4 TA's
# ENS 205 assigned 14 TA's
# ENS 208 assigned 6 TA's
# ENS 209 assigned 7 TA's
# ENS 211 assigned 5 TA's
# ENS 491 assigned 6 TA's
# GR 555 E assigned 4 TA's
# IE 301 assigned 4 TA's
# IE 302 assigned 3 TA's
# IE 303 assigned 5 TA's
# IE 304 assigned 4 TA's
# IE 305 assigned 4 TA's
# IE 309 assigned 4 TA's
# IE 401 assigned 3 TA's
# IE 402 assigned 4 TA's
# IE 403 assigned 3 TA's
# IE 405 assigned 3 TA's
# IE 407 assigned 0 TA's
# IE 408 assigned 1 TA's
# IE 409 assigned 2 TA's
# IE 413 assigned 1 TA's
# IE 430 assigned 1 TA's
# IE 454 assigned 1 TA's
# IE 471 assigned 1 TA's
# IE 472 assigned 1 TA's
# MAT 305 assigned 1 TA's
# MAT 312 assigned 4 TA's
# MAT 314 assigned 1 TA's
# MAT 404 assigned 1 TA's
# MAT 408 assigned 1 TA's
# MAT 511 assigned 1 TA's
# MATH 101 assigned 22 TA's
# MATH 102 assigned 13 TA's
# MATH 201 assigned 11 TA's
# MATH 203 assigned 10 TA's
# MATH 301 assigned 1 TA's
# MATH 306 assigned 4 TA's
# MATH 317 assigned 1 TA's
# MATH 414 assigned 0 TA's
# ME 301 assigned 3 TA's
# ME 303 assigned 3 TA's
# ME 304 assigned 0 TA's
# ME 307 assigned 3 TA's
# ME 308 assigned 3 TA's
# ME 402 assigned 2 TA's
# ME 403 assigned 3 TA's
# ME 405 assigned 1 TA's
# ME 407 assigned 2 TA's
# ME 409 assigned 2 TA's
# ME 435 assigned 1 TA's
# ME 480 assigned 0 TA's
# MJC 100 assigned 3 TA's
# NS 101 assigned 19 TA's
# NS 102 assigned 15 TA's
# NS 201 assigned 3 TA's
# NS 206 assigned 1 TA's
# NS 207 assigned 4 TA's
# NS 213 assigned 1 TA's
# NS 222 assigned 1 TA's
# PHD 100 assigned 0 TA's
# PHYS 303 assigned 0 TA's
# PHYS 401 assigned 0 TA's
# PHYS 412 assigned 0 TA's
# PHYS 438 assigned 0 TA's
# PROJ 102 assigned 3 TA's
# TLL 101 TLL 101 assigned 0 TA's

# %% [markdown]
# ## Number of Ta's for each program

# %%
top_programs = TA_df['Program'].value_counts()
print(type(top_programs))
keys = top_programs.keys()
vals = top_programs .values
plt.bar(keys, np.divide(list(vals), sum(vals)), label="Real distribution")
course_array = top_programs.keys()
# Out:
# <class 'pandas.core.series.Series'>

# %%
plt.bar(keys, np.divide(list(vals), sum(vals)), label="Real distribution")
# Out:
# <BarContainer object of 9 artists>

# %%
class HashNode :
    course : str # course name
    program : str # course program 
    info_list : dict # list of TA's assigned to that course wrt their programs # each node contains program and count
        
    def __init__(self, course, program , infolist):
        self.course = course
        self.program = program
        self.info_list = infolist

# %%
class Node :
    program : str
    info_list : dict
    
    def __init__(self,program,info_list) :
        self.program = program
        self.info_list = info_list

# %%
print(course_array)
# Out:
# Index(['MAT', 'IE', 'ME', 'BIO', 'CS', 'EE', 'MATH', 'MFE', 'PHYS'], dtype='object')

# %%
def findProgram(course_name,course_array) :
    flag = False
    if "MATH" in course_name :
        # i had to do this since a collision with MAT and MATH can occur beacuse i am looking for the substrings
        # ask for any solutions ?
        flag = True
        return "MATH"  
    else :
        for i in range(len(course_array)) :
            if course_array[i] in course_name :
                flag = True
                return course_array[i]
    if flag == False :
        return 'OTHER' # for common courses

# %%
def findTAprogram_update_version(ta_array,course_array,return_dict) : # returns a dictionary of programs
    for i in range(len(ta_array)):
        if "MATH" in ta_array[i] :
                try:
                    return_dict['MATH'] = return_dict['MATH'] + 1
                except KeyError as e :
                    return_dict['MATH'] = 1
                continue
        for j in range(len(course_array)) :    
            if course_array[j] in ta_array[i]: # in means search whether a substring occurs in that string
                try :
                    return_dict[course_array[j]] = return_dict[course_array[j]] + 1 # if exists , increment
                except KeyError as e :
                    return_dict[course_array[j]] = 1# if not exists , create
   # print(return_dict)

# %%
def findTAprogram(ta_array,course_array) : # returns a dictionary of programs
    return_dict = {} # an empty dictionary
    for i in range(len(ta_array)):
        if "MATH" in ta_array[i] :
                try:
                    return_dict['MATH'] = return_dict['MATH'] + 1
                except KeyError as e :
                    return_dict['MATH'] = 1
                continue
        for j in range(len(course_array)) :    
            if course_array[j] in ta_array[i]: # in means search whether a substring occurs in that string
                try :
                    return_dict[course_array[j]] = return_dict[course_array[j]] + 1 # if exists , increment
                except KeyError as e :
                    return_dict[course_array[j]] = 1# if not exists , create
   # print(return_dict)
    return return_dict

# %%
def createNode(series_object) :
    ta_string = series_object[-1] # assigned teaching grads column
    course_name = series_object[1] # refers to course name
    ta_list = ta_string.split('\n') # 
    program = findProgram(course_name,course_array)
    ta_dict = findTAprogram(ta_list,course_array)
   # print(ta_dict)
    X = HashNode(course_name,program,ta_dict)
    return X

# %%
course_table = {} # a hashtable implemented with seperate chaining methodology
program_table = {} # a hashtable implemented with seperate chaining methodology

print(course_n_rows)
for i in range(1,course_n_rows) :
    series_object = Course_df.loc[i]
    program = findProgram(series_object[1],course_array) 
    try :
        course_table[program].append(createNode(series_object))
        
    except KeyError as e :
        mylist = []
        mylist.append(createNode(series_object))
        course_table[program] = mylist
# Out:
# 103

# %%
print

# %%
print(course_table['MATH'][0].course)
print(course_table['MATH'][0].info_list)
# Out:
# MATH 101
# {'BIO': 4, 'MAT': 8, 'EE': 3, 'ME': 4, 'MATH': 3}

# %%
def createProgramTable(program_table,program,course_array) :
    return_dict = {}
    for i in range(1,course_n_rows) :
        if findProgram(Course_df.at[i,'Name'],course_array) == program : 
            ta_array = Course_df.at[i,'Assigned Teaching Grads'].split('\n')
            findTAprogram_update_version(ta_array,course_array,return_dict) # update the return dict
    
    #after collecting all the programs
    X = Node(program,return_dict)
    program_table[program] = X

# %%
for i in range(len(course_array)) :
    program = course_array[i]
    createProgramTable(program_table, program,course_array)

# %%
print(program_table["MATH"].info_list)
# Out:
# {'BIO': 5, 'MAT': 15, 'EE': 7, 'ME': 11, 'MATH': 18, 'PHYS': 3, 'MFE': 1, 'CS': 2}

# %%
def getTa(course_name) :
    for i in range(1,course_n_rows) :
        if Course_df.at[i,'Name'] == course_name :
            return (len(Course_df.at[i,'Assigned Teaching Grads'].splitlines()))

# %%
fall_2016df.head()

# %%
def getStudent(course_name) :
    to_return = 0
    for i in range(student_n_rows) : 
        if fall_2016df.at[i,'SC'] == course_name :
            to_return = to_return + fall_2016df.at[i,'Enrl-last']
        
    return to_return

# %%
def ta_student_ratio(course_name,coursename) :
    student_number = 0
    ta_number = 0 
    student_number = getStudent(coursename)
    ta_number = getTa(course_name)
    return ta_number/student_number

# %%
print(ta_student_ratio("IE 302","IE302"))
# Out:
# 0.016853932584269662

# %%
#Course_df = Course_df.to_excel("ens491.xlsx")

# %%
TA_df= TA_df.to_excel("tapow.xlsx")

# %%
artun = (Course_df.loc[1]['Assigned Teaching Grads'].splitlines())
print("10 " in artun[0].split(",")[2])
# Out:
# True

# %%
def get_course_object(course_name) :
    for i in range(1,course_n_rows) :
        if Course_df.at[i,'Name']  == course_name :
            return Course_df.loc[i] # returns the corresponding row

# %%
def get_ta_hour(assigned_teaching_grads) : 
    return_value = 0
    print(assigned_teaching_grads)
    #assigned_teaching_grads is a string
    assigned_teaching_grads = assigned_teaching_grads.splitlines()
    for i in range(len(assigned_teaching_grads)) :
        if "5" in assigned_teaching_grads[i].split(',')[2] and "15" not in assigned_teaching_grads[i].split(',')[2] :
            return_value = return_value + 5
        elif "10"in assigned_teaching_grads[i].split(',')[2] :
            return_value = return_value + 10 
        elif "15" in assigned_teaching_grads[i].split(',')[2] :
            return_value = return_value + 15 
        elif "20" in assigned_teaching_grads[i].split(',')[2] :
            return_value = return_value + 20 
        
            
    return return_value

# %%
def get_student_sum(dataframe,course_name) :
    sum_value = 0
    course_name = course_name.replace(" ","")
    for i in range(student_n_rows) :
        if dataframe.at[i,"SC"] == course_name :
            sum_value = sum_value + int(dataframe.at[i,"Enrl-last"])
            
    return sum_value

# %%
def student_ta_hour_ratio(course_name) :
    series_object = get_course_object(course_name)
    sum_ta_hours = get_ta_hour(series_object['Assigned Teaching Grads'])
    print(sum_ta_hours)
    sum_students = get_student_sum(fall_2016df,course_name)
    print(sum_students)
    return sum_ta_hours/sum_students

# %% [markdown]
# ## Number of Students / TA_hours

# %%
print("Ratio is: ",student_ta_hour_ratio("CS 201"))
# Out:
# Gizem Gezici (65246, CS, 10 hours)
# Yasin Findik (65636, CS, 10 hours)
# Yusuf Izmirlioglu (65382, CS, 10 hours)
# Ece Egemen (65396, CS, 20 hours)
# Artrim Kjamilji (65374, CS, 10 hours)
# Muge Segmen (65259, CS, 10 hours)
# Omid Khorsand Kazemy (65769, CS, 20 hours)
# Baran Usta (65595, CS, 20 hours)
# Beste Seymen (65421, CS, 10 hours)
# Hemed Hamisi Kaporo (65785, CS, 20 hours)
# Mahsa Mozaffari (65720, CS, 20 hours)
# Sara Atito Ali Ahmed (65531, CS, 20 hours)
# Saeed Nourizadeh (65682, CS, 10 hours)
# Ataman Girisken (65245, CS, 10 hours)
# Ibrahim Faruk Yalciner (65699, CS, 10 hours)
# 210
# 390
# Ratio is:  0.5384615384615384
