# %%
>>> import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
import seaborn as sns # a visualization library from matplotlib
from math import sin, cos, sqrt, atan2, radians
import json
import pprint
import ast

# %%
Course_df = pd.read_excel(r"/Users/artun/Desktop/ens491:burak_kocuk/2015-2016-fall-course.xlsx") #course list
TA_df =pd.read_excel(r"/Users/artun/Desktop/ens491:burak_kocuk/2015-2016-fall-TA.xlsx") # TA preference list

# %%
n_rows, n_columns = Course_df.shape  # get the shape of dataframe
print("Shape of course dataframe is")
print("number of rows: {}, number of columns: {}".format(n_rows, n_columns))
# Out:
# Shape of course dataframe is
# number of rows: 114, number of columns: 9

# %%
n_rows, n_columns = TA_df.shape  # get the shape of dataframe
print("Shape of TA dataframe is")
print("number of rows: {}, number of columns: {}".format(n_rows, n_columns))
# Out:
# Shape of TA dataframe is
# number of rows: 292, number of columns: 11

# %%
print("292 TA's assigned to FENS courses during fall semester of 2015/2016")
# Out:
# 292 TA's assigned to FENS courses during fall semester of 2015/2016

# %%
TA_df.head(292)
# Out:
#      Student ID                           Name Degree Program  Hours Assigned  \
# 0         19928         Abba Ibrahim \nRamadan     MS    MATH              20
# 1         18282  Abdolali \nKhalili Sadaghiani    PHD      ME              20
# 2         17061           Abdülkadir \nCanatar     MS    PHYS              20
# 3         19996              Abdullahi \nAdamu     MS      EE              10
# 4         14277            Abdurrahman \nBurak     MS      EE              10
# 5         20205               Adnan \nTaşdemir    PHD     MAT              10
# 6         17198                 Ahmed \nNouman    PHD      ME              10
# 7         10024                Ahmet \nŞahinöz    PHD      ME              10
# 8         13953                Ahmet Can\nMert     MS      EE              10
# 9         10613          Ahmet Selim\nPehlivan    PHD      ME              10
# 10        18632                  Ahsen \nŌzcan     MS     BIO              10
# 11        15494                  Alara \nGüler     MS      IE              20
# 12        18370          Ali \nAnsari Hamedani    PHD     MAT              10
# 13        17205               Ali \nAsgharpour    PHD    PHYS              10
# 14        19940                Ali \nMohammadi    PHD      ME              10
# 15        19948              Ali \nNadernezhad    PHD     MAT              10
# 16        15931                   Ali \nTufani    PHD     MAT              10
# 17        15081              Ali Kutlu\nDurşen    PHD    MATH              20
# 18         5244               Alper Emrah\nGür     MS    MATH              20
# 19        20177             Amin \nBagherzadeh     MS      IE              20
# 20        21425              Amin \nFarajzadeh     MS      EE              20
# 21        21441                  Amin \nHodaei     MS     MAT              20
# 22        15928                  Amin \nRahmat    PHD      ME              10
# 23        18218            Amir \nEmami Gohari     MS      IE              10
# 24        19908              Anaguli \nAbulizi     MS     MAT              10
# 25        15474               Arman \nGalioğlu     MS      EE              10
# 26        17193               Arsalan \nJaveed    PHD      CS              20
# 27        19955              Artrim \nKjamilji    PHD      CS              10
# 28        16338                   Arzu \nŌzbey    PHD      ME              10
# 29        17213                Ashish \nPandey    PHD     MAT              10
# ..          ...                            ...    ...     ...             ...
# 262        9437                    Talha \nBoz    PHD      ME              20
# 263       21474          Tandaç Fürkan \nGüçlü    PHD     BIO              10
# 264       19950               Tekgül \nKalaycı    PHD    MATH              20
# 265       15122                 Tolga \nÇağlar    PHD    PHYS              20
# 266       18623                   Tuğçe \nOruç     MS     BIO              20
# 267       14804            Tugce Ayca\nTekiner    PHD     BIO              20
# 268       21468                 Tuğdem \nMuslu    PHD     BIO              10
# 269       15135                Ümmühan \nAkbay    PHD      IE              10
# 270       21404              Umut Can \nÇakmak     MS      IE              20
# 271       20111                   Utku \nGüçlü     MS     MAT              10
# 272       16331       Vahid \nSazgari Ardakani    PHD    PHYS              10
# 273       18389         Vahid \nTavakol Aghaei    PHD      ME              10
# 274       21432      Wisdom Chukwunwike\nAgboh     MS      ME              20
# 275       14281                Yağmur \nŞişman     MS      ME              10
# 276       14217                  Yalçın \nAkın     MS      ME              20
# 277       21475              Yalda \nEsmizadeh    PHD      IE              20
# 278       21517              Yaser \nMohammadi     MS      IE              10
# 279       13922               Yelda \nYorulmaz     MS     MAT              10
# 280       18241                  Yonca \nYakut    PHD     MAT              10
# 281       18372                  Yunus \nAkkoç    PHD     BIO              10
# 282       21458            Yusuf \nİzmirlioğlu    PHD      CS              10
# 283       21413            Yusuf Mert\nŞentürk     MS      ME              20
# 284       18219             Zahed \nShahmoradi     MS      IE              10
# 285       19938       Zahra \nBarzegar Osgouei    PHD      IE              10
# 286       17207        Zahra \nGoharibajestani    PHD     MAT              20
# 287       19998          Zeki Semih \nPehlivan     MS      ME              10
# 288       18641                  Zeynep \nAdak    PHD      IE              20
# 289       14318                   Zeynep \nBoz     MS      IE              20
# 290       19954        Ziynet Nesibe\nDayıoğlu    PHD      CS               0
# 291       20043              Zohreh \nAliabadi    PHD    MATH              20
#
#      Hours Requested                                  Requested Courses  \
# 0                 20  1- MATH 101 (380 / 350)\n2- MATH 102 (130 / 17...
# 1                 20                                                NaN
# 2                 20                                                NaN
# 3                 10  1- ENS 211 (60 / 75)\n2- MATH 203 (130 / 113)\...
# 4                 10  1- EE 303 (30 / 15)\n2- EE 480 (0 / 5)\n3- ENS...
# 5                 10  1- PHYS 302 (10 / 10)\n2- MATH 101 (380 / 350)...
# 6                 10  1- CS 404 (10 / 20)\n2- EE 417 (30 / 35)\n3- M...
# 7                 10  1- ME 301 (30 / 46)\n2- ENS 209 (100 / 93)\n3-...
# 8                 10  1- EE 401 (10 / 10)\n2- EE 473 (10 / 15)\n3- C...
# 9                 10                                                NaN
# 10                10                                                NaN
# 11                20  1- IE 405 (30 / 40)\n2- IE 305 (60 / 45)\n3- E...
# 12                10  1- ENS 205 (150 / 110)\n2- MAT 312 (40 / 15)\n...
# 13                10                                                NaN
# 14                10  1- ME 307 (20 / 25)\n2- MATH 101 (380 / 350)\n...
# 15                10  1- ENS 315 (20 / 20)\n2- MAT 408 (10 / 5)\n3- ...
# 16                10  1- MAT 401 (10 / 5)\n2- NS 102 (170 / 163)\n3-...
# 17                20                                                NaN
# 18                20                                                NaN
# 19                20                                                NaN
# 20                20  1- EE 413 (0 / 5)\n2- EE 313 (10 / 15)\n3- NS ...
# 21                20                             1- ENS 205 (150 / 110)
# 22                10                                                NaN
# 23                10                                                NaN
# 24                10  1- MATH 101 (380 / 350)\n2- IE 304 (70 / 40)\n...
# 25                10  1- EE 480 (0 / 5)\n2- ENS 203 (50 / 100)\n3- E...
# 26                20  1- CS 307 (20 / 30)\n2- CS 201 (155 / 151)\n3-...
# 27                10  1- CS 201 (155 / 151)\n2- MATH 203 (130 / 113)...
# 28                10                                1- ME 409 (10 / 20)
# 29                10  1- ENS 205 (150 / 110)\n2- MAT 401 (10 / 5)\n3...
# ..               ...                                                ...
# 262               20  1- ME 301 (30 / 46)\n2- MATH 203 (130 / 113)\n...
# 263               10  1- BIO 452 (10 / 10)\n2- NS 102 (170 / 163)\n3...
# 264               20  1- MATH 101 (380 / 350)\n2- MATH 102 (130 / 17...
# 265               20  1- PHYS 438 (10 / 10)\n2- NS 101 (350 / 207)\n...
# 266               20  1- BIO 466 (20 / 10)\n2- NS 102 (170 / 163)\n3...
# 267               20        1- BIO 407 (20 / 10)\n2- NS 102 (170 / 163)
# 268               10  1- BIO 407 (20 / 10)\n2- BIO 447 (10 / 10)\n3-...
# 269               10                                                NaN
# 270               20  1- IE 301 (40 / 45)\n2- ENS 208 (90 / 75)\n3- ...
# 271               10                                                NaN
# 272               10                               1- ENS 315 (20 / 20)
# 273               10  1- MATH 101 (380 / 350)\n2- ME 303 (50 / 38)\n...
# 274               20  1- ME 312 (30 / 30)\n2- ME 303 (50 / 38)\n3- M...
# 275               10         1- ENS 209 (100 / 93)\n2- ME 409 (10 / 20)
# 276               20  1- ME 308 (40 / 30)\n2- CS 303 (60 / 80)\n3- M...
# 277               20  1- IE 430 (20 / 20)\n2- IE 301 (40 / 45)\n3- I...
# 278               10                                                NaN
# 279               10  1- ENS 205 (150 / 110)\n2- MATH 101 (380 / 350...
# 280               10       1- MAT 305 (10 / 5)\n2- MATH 101 (380 / 350)
# 281               10  1- BIO 306 (20 / 20)\n2- BIO 321 (20 / 25)\n3-...
# 282               10                                                NaN
# 283               20  1- ME 312 (30 / 30)\n2- MATH 102 (130 / 179)\n...
# 284               10  1- IE 301 (40 / 45)\n2- IE 408 (0 / 20)\n3- IE...
# 285               10  1- IE 481 (20 / 15)\n2- IE 482 (20 / 10)\n3- I...
# 286               20                                                NaN
# 287               10  1- ME 402 (20 / 10)\n2- MATH 101 (380 / 350)\n...
# 288               20  1- IE 305 (60 / 45)\n2- IE 413 (20 / 30)\n3- I...
# 289               20  1- IE 302 (60 / 35)\n2- IE 415 (10 / 20)\n3- E...
# 290                0  1- MATH 102 (130 / 179)\n2- MATH 201 (165 / 12...
# 291               20                                                NaN
#
#     Assigned Course 1    CRN 1 Assigned Course 2    CRN 2
# 0            MATH 203  10401.0               NaN      NaN
# 1            MATH 101  10536.0               NaN      NaN
# 2              NS 101  10616.0               NaN      NaN
# 3             ENS 211  10317.0               NaN      NaN
# 4              EE 303  10923.0               NaN      NaN
# 5              NS 102  10631.0               NaN      NaN
# 6            MATH 102  10595.0               NaN      NaN
# 7            MATH 102  10595.0          \nME 301  10419.0
# 8              EE 401  10927.0               NaN      NaN
# 9             ENS 209  10302.0               NaN      NaN
# 10             NS 201  10440.0               NaN      NaN
# 11             IE 305  10780.0               NaN      NaN
# 12            ENS 205  10292.0               NaN      NaN
# 13             NS 102  10631.0               NaN      NaN
# 14             ME 307  10424.0               NaN      NaN
# 15            MAT 408  11161.0               NaN      NaN
# 16             NS 102  10631.0               NaN      NaN
# 17           MATH 201  10399.0               NaN      NaN
# 18           MATH 201  10399.0               NaN      NaN
# 19             IE 303  10764.0               NaN      NaN
# 20             NS 101  10616.0               NaN      NaN
# 21            ENS 205  10292.0               NaN      NaN
# 22           MATH 102  10595.0               NaN      NaN
# 23            ENS 208  10332.0               NaN      NaN
# 24             NS 101  10616.0               NaN      NaN
# 25            ENS 203  10281.0               NaN      NaN
# 26             CS 204  10219.0               NaN      NaN
# 27             CS 204  10219.0               NaN      NaN
# 28             ME 409  10435.0               NaN      NaN
# 29           PROJ 102  10637.0               NaN      NaN
# ..                ...      ...               ...      ...
# 262          MATH 203  10401.0               NaN      NaN
# 263            NS 101  10616.0               NaN      NaN
# 264          MATH 101  10536.0               NaN      NaN
# 265          PHYS 438  11137.0          \nIF 200  10377.0
# 266           BIO 466  10194.0               NaN      NaN
# 267            NS 101  10616.0               NaN      NaN
# 268            NS 102  10631.0               NaN      NaN
# 269            IE 454  10842.0               NaN      NaN
# 270           ENS 208  10332.0               NaN      NaN
# 271            NS 101  10616.0               NaN      NaN
# 272            NS 101  10616.0               NaN      NaN
# 273           ENS 211  10317.0               NaN      NaN
# 274            ME 312  10429.0          \nME 407  10433.0
# 275           ENS 209  10302.0               NaN      NaN
# 276          MATH 203  10401.0               NaN      NaN
# 277            IE 481  11064.0               NaN      NaN
# 278            IE 402  10794.0               NaN      NaN
# 279           MAT 312  10382.0               NaN      NaN
# 280           MAT 305  10378.0               NaN      NaN
# 281           BIO 306  10180.0               NaN      NaN
# 282            CS 201  10204.0               NaN      NaN
# 283          MATH 101  10536.0               NaN      NaN
# 284            IE 304  10773.0               NaN      NaN
# 285           ENS 209  10302.0               NaN      NaN
# 286          CHEM 301  10202.0               NaN      NaN
# 287          MATH 101  10536.0               NaN      NaN
# 288            IE 304  10773.0               NaN      NaN
# 289            IE 302  10757.0               NaN      NaN
# 290               NaN      NaN               NaN      NaN
# 291          MATH 101  10536.0               NaN      NaN
#
# [292 rows x 11 columns]

# %%
Course_df.head(114)
# Out:
#          CRN      Name Section                           Title     Preferred  \
# 0        NaN       NaN     NaN                             NaN  Grad Program
# 1    10180.0   BIO 306       0                    Microbiology           NaN
# 2    10182.0   BIO 321       0                  Biochemistry I           NaN
# 3    10185.0   BIO 332       0                    Cell Biology           NaN
# 4    11162.0   BIO 407       0      Multicellular Organization           NaN
# 5    10186.0   BIO 445       0      Plant Tissue Culture Tech.           NaN
# 6    10191.0   BIO 447       0                  Plant Breeding           NaN
# 7    10192.0   BIO 452       0                      Immunology           NaN
# 8    10194.0   BIO 466       0  Biophysics: Molecules and Sys.           NaN
# 9    10202.0  CHEM 301       0             Inorganic Chemistry           NaN
# 10   11150.0  CHEM 405       0                Electrochemistry           NaN
# 11   11155.0  CHEM 421       0           Clean Coal Technology           NaN
# 12   10204.0    CS 201       0       Introduction to Computing           NaN
# 13   10219.0    CS 204       0            Advanced Programming           NaN
# 14   10224.0    CS 300       0                 Data Structures           NaN
# 15   10459.0    CS 302       0     Formal Lang&Automata Theory           NaN
# 16   10461.0    CS 303       0     Logic&Digital System Design           NaN
# 17   10469.0    CS 307       0               Operating Systems           NaN
# 18   10226.0    CS 400       0       Logic in Computer Science           NaN
# 19   10263.0    CS 402       0                 Compiler Design           NaN
# 20   10264.0    CS 404       0         Artificial Intelligence           NaN
# 21   10265.0    CS 405       0               Computer Graphics           NaN
# 22   10267.0    CS 408       0               Computer Networks           NaN
# 23   10271.0    CS 411       0                    Cryptography           NaN
# 24   10272.0    CS 412       0                Machine Learning           NaN
# 25   10923.0    EE 303       0      Analog Integrated Circuits           NaN
# 26   10921.0    EE 307       0      Semiconductor Phy.&Devices           NaN
# 27   10929.0    EE 311       0  Int.to Signal Pro.&Infor.Syst.           NaN
# 28   10931.0    EE 313       0  Intro.to Communication Systems           NaN
# 29   10927.0    EE 401       0           Vlsi Systems Design I           NaN
# ..       ...       ...     ...                             ...           ...
# 84   10413.0  MATH 301       0   Int. to Mathematical Analysis           NaN
# 85   10403.0  MATH 306       0           Statistical Modelling           NaN
# 86   10476.0  MATH 317       0        Elementary Number Theory           NaN
# 87   11147.0  MATH 401       0         Intr. to Func. Analysis           NaN
# 88   10419.0    ME 301       0            Mechanical Systems I           NaN
# 89   10420.0    ME 303       0           Control System Design           NaN
# 90   10424.0    ME 307       0                  Fluid Dynamics           NaN
# 91   10426.0    ME 308       0              Industrial Control           NaN
# 92   10429.0    ME 312       0    Analysis&Synth.of Mechanisms           NaN
# 93   10431.0    ME 402       0                      Plasmonics           NaN
# 94   10433.0    ME 407       0                Embedded Systems           NaN
# 95   10435.0    ME 409       0     Foundations of Microsystems           NaN
# 96   10437.0    ME 420       0       Ren.&Sust. Energy Systems           NaN
# 97   11143.0    ME 480       0       Spc.Top.in Mechatronics I           NaN
# 98   10719.0   MJC 100       0       Majors:informative Course           NaN
# 99   10616.0    NS 101       A             Science of Nature I           NaN
# 100  10631.0    NS 102       0            Science Of Nature Ii           NaN
# 101  10440.0    NS 201       0                Discovering Life           NaN
# 102  10442.0    NS 206       0            Inside The Milky Way           NaN
# 103  10443.0    NS 207       0               Organic Chemistry           NaN
# 104  10478.0    NS 213       0       Basic Concepts of Physics           NaN
# 105  10445.0    NS 222       0   Planetary Sys.&Extraslr Plane           NaN
# 106  20000.0   PHD 100       1                 Qualifying Exam             0
# 107  10452.0  PHYS 302       0             Solid State Physics           NaN
# 108  10446.0  PHYS 303       0             Quantum Mechanics I           NaN
# 109  10454.0  PHYS 401       0             Classical Mechanics           NaN
# 110  10448.0  PHYS 412       0           Statistical Mechanics           NaN
# 111  11137.0  PHYS 438       0  Phase Trans.&Renorm.-Group Th.           NaN
# 112  10637.0  PROJ 102       0                  Project Course           NaN
# 113  10158.0   SPS 315       0     Analysis of Social Networks           NaN
#
#      Hours Assigned  Hours Requested  \
# 0               NaN              NaN
# 1              20.0             20.0
# 2              20.0             25.0
# 3              30.0             15.0
# 4              20.0             10.0
# 5              10.0             15.0
# 6              10.0             10.0
# 7              10.0             10.0
# 8              20.0             10.0
# 9              30.0             10.0
# 10              0.0              5.0
# 11              0.0              5.0
# 12            155.0            151.0
# 13             50.0             43.0
# 14             30.0             38.0
# 15             15.0             15.0
# 16             60.0             80.0
# 17             20.0             30.0
# 18             10.0              5.0
# 19              5.0              5.0
# 20             10.0             20.0
# 21             20.0             15.0
# 22             30.0             50.0
# 23             15.0             10.0
# 24             10.0             15.0
# 25             30.0             15.0
# 26             10.0             10.0
# 27             10.0             15.0
# 28             10.0             15.0
# 29             10.0             10.0
# ..              ...              ...
# 84             20.0             15.0
# 85             60.0             75.0
# 86              0.0             10.0
# 87              0.0              5.0
# 88             30.0             46.0
# 89             50.0             38.0
# 90             20.0             25.0
# 91             40.0             30.0
# 92             30.0             30.0
# 93             20.0             10.0
# 94             10.0             20.0
# 95             10.0             20.0
# 96              0.0             15.0
# 97             20.0              5.0
# 98             40.0             60.0
# 99            350.0            207.0
# 100           170.0            163.0
# 101            20.0             30.0
# 102            10.0             30.0
# 103            30.0             35.0
# 104            10.0             20.0
# 105            10.0             20.0
# 106             0.0              5.0
# 107            10.0             10.0
# 108             0.0             10.0
# 109             0.0              5.0
# 110             0.0              5.0
# 111            10.0             10.0
# 112            40.0             60.0
# 113             0.0              5.0
#
#                              Requesting Teaching Grads  \
# 0                                                  NaN
# 1    1-Secil Erbil ( 64207 ) (10 / 10)\n1-Yunus Akk...
# 2    2-Secil Erbil ( 64207 ) (10 / 10)\n2-Yunus Akk...
# 3    1-Ersoy Colak ( 63844 ) (20 / 20)\n2-Ezgi Baki...
# 4    1-Tugce Ayca Tekiner ( 64138 ) (20 / 20)\n1-Ay...
# 5    1-Melike Cokol ( 64148 ) (10 / 10)\n2-Ersoy Co...
# 6    2-Aydan Sarac ( 63781 ) (0 / 10)\n2-Kadriye Ka...
# 7    1-Nur Mehpare Kocaturk ( 64026 ) (10 / 10)\n1-...
# 8    1-Tugce Oruc ( 63750 ) (20 / 20)\n2-Haleh Abdi...
# 9    2-Muhammad Faisal Jamil ( 63841 ) (10 / 10)\n4...
# 10   1-Sahl Sadeghi ( 64159 ) (10 / 10)\n2-Begum Ya...
# 11   1-Sahl Sadeghi ( 64159 ) (10 / 10)\n2-Begum Ya...
# 12   1-Mehmet Cagri Calpur ( 64197 ) (20 / 20)\n1-R...
# 13   2-Deniz Marlali ( 63735 ) (10 / 10)\n2-Omid Kh...
# 14   1-Damla Arifoglu ( 64012 ) (20 / 20)\n1-Hanefi...
# 15   2-Ezgi Demirel ( 63726 ) (10 / 10)\n2-Damla Ar...
# 16   1-Cagla Koca ( 63958 ) (10 / 10)\n2-Sertac Kar...
# 17   1-Arsalan Javeed ( 63975 ) (20 / 20)\n1-Mert K...
# 18                  1-Ezgi Demirel ( 63726 ) (10 / 10)
# 19   1-Sertac Karahoda ( 63742 ) (10 / 10)\n4-Arsal...
# 20   1-Ahmed Nouman ( 64216 ) (10 / 10)\n1-Ibrahim ...
# 21   1-Mert Toka ( 63906 ) (10 / 10)\n1-Erdem Kaya ...
# 22   2-Ramin Armanfar ( 63916 ) (20 / 20)\n3-Omer M...
# 23   2-Ramin Armanfar ( 63916 ) (20 / 20)\n3-Omer M...
# 24   1-Murat Can Ozdemir ( 64204 ) (10 / 10)\n2-Ste...
# 25   1-Shahbaz Abbasi ( 63866 ) (10 / 10)\n1-Abdurr...
# 26   2-Atia Shafique ( 64214 ) (10 / 10)\n3-Can Cal...
# 27   2-Mastaneh Torkamani Azar ( 63761 ) (20 / 20)\...
# 28   1-Muhammad Sohaib Amjad ( 63760 ) (10 / 10)\n2...
# 29                1-Ahmet Can Mert ( 63956 ) (10 / 10)
# ..                                                 ...
# 84   1-Hailu Bikila Yadeta ( 63755 ) (20 / 20)\n2-G...
# 85   1-Mehmet Kubilay Caglar ( 63743 ) (20 / 20)\n1...
# 86   2-Burcin Gunes ( 64151 ) (20 / 20)\n2-Selcen S...
# 87   2-Hailu Bikila Yadeta ( 63755 ) (20 / 20)\n4-E...
# 88   1-Ahmet sahinoz ( 64016 ) (10 / 10)\n1-Talha B...
# 89   1-Sanem Evren ( 64202 ) (20 / 20)\n1-Gokhan Al...
# 90   1-Ali Mohammadi ( 64096 ) (10 / 10)\n1-Morteza...
# 91   1-Dogacan Bilgili ( 64133 ) (10 / 10)\n1-Mert ...
# 92   1-Mustafa Yalcin ( 63953 ) (10 / 10)\n1-Yusuf ...
# 93   1-Eesa Rahimi ( 63986 ) (10 / 10)\n1-Zeki Semi...
# 94   1-Eesa Rahimi ( 63986 ) (10 / 10)\n1-Zeki Semi...
# 95   1-Arzu Ozbey ( 63964 ) (10 / 10)\n2-Yagmur sis...
# 96   1-Hakan Osman Caldag ( 64200 ) (20 / 20)\n4-Eb...
# 97               1-Soheila Zeinali ( 63780 ) (20 / 20)
# 98   1-Cagatay Yilmaz ( 63893 ) (10 / 10)\n3-Firat ...
# 99   1-Asli Yenenler ( 63730 ) (10 / 20)\n1-Babar H...
# 100  1-Bahriye Karakas ( 63884 ) (20 / 20)\n1-Ipek ...
# 101  1-Ronay Cetin ( 64252 ) (10 / 10)\n4-Nassur Mo...
# 102  1-Onur Catmabacak ( 63923 ) (10 / 10)\n1-Onder...
# 103  1-Muhammad Faisal Jamil ( 63841 ) (10 / 10)\n4...
# 104  1-Nassur Mohamed Ramadhan ( 64092 ) (10 / 10)\...
# 105  1-Nassur Mohamed Ramadhan ( 64092 ) (10 / 10)\...
# 106  1-Nassur Mohamed Ramadhan ( 64092 ) (10 / 10)\...
# 107  1-Adnan Tasdemir ( 64049 ) (10 / 10)\n2-Divya ...
# 108  1-Adnan Tasdemir ( 64049 ) (10 / 10)\n2-Divya ...
# 109  1-Adnan Tasdemir ( 64049 ) (10 / 10)\n2-Divya ...
# 110  1-Adnan Tasdemir ( 64049 ) (10 / 10)\n2-Divya ...
# 111                 1-Tolga Caglar ( 63894 ) (20 / 20)
# 112                 1-Tolga Caglar ( 63894 ) (20 / 20)
# 113  1-Burcu Gunes ( 64223 ) (10 / 10)\n3-Murat Can...
#
#                                Assigned Teaching Grads
# 0                                                  NaN
# 1    Esra Sinoplu (63770, BIO, 10 hours)\nYunus Akk...
# 2               Bahriye Karakas (63884, BIO, 20 hours)
# 3    Asma Abdullah Abdulwahab Al-murtadha (64036, B...
# 4                Burcu Alptekin (64100, BIO, 20 hours)
# 5                  Melike Cokol (64148, BIO, 10 hours)
# 6           Reyyan Fatima Bulut (63835, BIO, 10 hours)
# 7                 Bahar Shamloo (64139, BIO, 10 hours)
# 8                    Tugce Oruc (63750, BIO, 20 hours)
# 9    Zahra Goharibajestani (63981, MAT, 20 hours)\n...
# 10                                                None
# 11                                                None
# 12   Stefan Rabiger (63990, CS, 20 hours)\nInanc Ar...
# 13   Arsalan Javeed (63975, CS, 20 hours)\nArtrim K...
# 14   Hanefi Mercan (64135, CS, 10 hours)\nMehmet Ca...
# 15                Damla Arifoglu (64012, CS, 15 hours)
# 16   Atil Utku Ay (64213, CS, 5 hours)\nCagla Koca ...
# 17              Mert Kemal Erpam (63723, CS, 20 hours)
# 18                  Ezgi Demirel (63726, CS, 10 hours)
# 19                Sertac Karahoda (63742, CS, 5 hours)
# 20        Ibrahim Faruk Yalciner (64177, CS, 10 hours)
# 21   Gokhan Gokturk (64005, CS, 10 hours)\nErdem Ka...
# 22   Ramin Armanfar (63916, CS, 20 hours)\nOmer Mer...
# 23   Leyli Javid Khayati (64178, CS, 10 hours)\nAti...
# 24       Mostafa Mehdipour Ghazi (63828, EE, 10 hours)
# 25   Berktug Ustundag (63886, EE, 10 hours)\nAbdurr...
# 26                Elif Gul Ozkan (63998, EE, 10 hours)
# 27                Oguzcan Zengin (64180, EE, 10 hours)
# 28         Muhammad Sohaib Amjad (63760, EE, 10 hours)
# 29                Ahmet Can Mert (63956, EE, 10 hours)
# ..                                                 ...
# 84         Hailu Bikila Yadeta (63755, MATH, 20 hours)
# 85   Mehmet Emre Ozfatura (63712, EE, 20 hours)\nMe...
# 86                                                None
# 87                                                None
# 88   Esra Yuksel (64046, IE, 20 hours)\nErdem Gorgu...
# 89   Sanem Evren (64202, ME, 20 hours)\nGokhan Alca...
# 90   Morteza Ghorbani (63749, ME, 10 hours)\nAli Mo...
# 91   Mert Mehmet Gulhan (64124, ME, 10 hours)\nHakk...
# 92   Gokay Coruhlu (63895, ME, 10 hours)\nMustafa Y...
# 93   Eesa Rahimi (63986, ME, 10 hours)\nMuhammed Al...
# 94      Wisdom Chukwunwike Agboh (64116, ME, 10 hours)
# 95                    Arzu Ozbey (63964, ME, 10 hours)
# 96                                                None
# 97               Soheila Zeinali (63780, ME, 20 hours)
# 98   Secil Erbil (64207, BIO, 10 hours)\nMuhammed K...
# 99   Ezgi Dundar Tekkaya (64066, MAT, 10 hours)\nSo...
# 100  Aysu Yurdusen (63982, MAT, 20 hours)\nDeniz Ko...
# 101  Ronay Cetin (64252, BIO, 10 hours)\nAhsen Ozca...
# 102               Babar Hussain (63901, BIO, 10 hours)
# 103  Ece Arici (63817, MAT, 10 hours)\nSahl Sadeghi...
# 104          Murat Gokhan Eskin (64122, MAT, 10 hours)
# 105         Deniz Gulfem Ozturk (64023, BIO, 10 hours)
# 106                                               None
# 107             Melihat Madran (64226, PHYS, 10 hours)
# 108                                               None
# 109                                               None
# 110                                               None
# 111               Tolga Caglar (63894, PHYS, 10 hours)
# 112  Ashish Pandey (63737, MAT, 10 hours)\nHalise B...
# 113                                               None
#
# [114 rows x 9 columns]

# %%
TA_df.dtypes
# Out:
# Student ID             int64
# Name                  object
# Degree                object
# Program               object
# Hours Assigned         int64
# Hours Requested        int64
# Requested Courses     object
# Assigned Course 1     object
# CRN 1                float64
# Assigned Course 2     object
# CRN 2                float64
# dtype: object

# %%
Course_df.dtypes
# Out:
# CRN                          float64
# Name                          object
# Section                       object
# Title                         object
# Preferred                     object
# Hours Assigned               float64
# Hours Requested              float64
# Requesting Teaching Grads     object
# Assigned Teaching Grads       object
# dtype: object

# %% [markdown]
# # Handling Dirty Data

# %%
# TA dataframe first
TA_df = TA_df.fillna(0) # NaN values are cumbersome values. Change all to 0
TA_df.head()
# Out:
#    Student ID                           Name Degree Program  Hours Assigned  \
# 0       19928         Abba Ibrahim \nRamadan     MS    MATH              20
# 1       18282  Abdolali \nKhalili Sadaghiani    PHD      ME              20
# 2       17061           Abdülkadir \nCanatar     MS    PHYS              20
# 3       19996              Abdullahi \nAdamu     MS      EE              10
# 4       14277            Abdurrahman \nBurak     MS      EE              10
#
#    Hours Requested                                  Requested Courses  \
# 0               20  1- MATH 101 (380 / 350)\n2- MATH 102 (130 / 17...
# 1               20                                                  0
# 2               20                                                  0
# 3               10  1- ENS 211 (60 / 75)\n2- MATH 203 (130 / 113)\...
# 4               10  1- EE 303 (30 / 15)\n2- EE 480 (0 / 5)\n3- ENS...
#
#   Assigned Course 1    CRN 1 Assigned Course 2  CRN 2
# 0          MATH 203  10401.0                 0    0.0
# 1          MATH 101  10536.0                 0    0.0
# 2            NS 101  10616.0                 0    0.0
# 3           ENS 211  10317.0                 0    0.0
# 4            EE 303  10923.0                 0    0.0

# %%
Course_df = Course_df.fillna(0)
Course_df.head()
# Out:
#        CRN     Name Section                       Title     Preferred  \
# 0      0.0        0       0                           0  Grad Program
# 1  10180.0  BIO 306       0                Microbiology             0
# 2  10182.0  BIO 321       0              Biochemistry I             0
# 3  10185.0  BIO 332       0                Cell Biology             0
# 4  11162.0  BIO 407       0  Multicellular Organization             0
#
#    Hours Assigned  Hours Requested  \
# 0             0.0              0.0
# 1            20.0             20.0
# 2            20.0             25.0
# 3            30.0             15.0
# 4            20.0             10.0
#
#                            Requesting Teaching Grads  \
# 0                                                  0
# 1  1-Secil Erbil ( 64207 ) (10 / 10)\n1-Yunus Akk...
# 2  2-Secil Erbil ( 64207 ) (10 / 10)\n2-Yunus Akk...
# 3  1-Ersoy Colak ( 63844 ) (20 / 20)\n2-Ezgi Baki...
# 4  1-Tugce Ayca Tekiner ( 64138 ) (20 / 20)\n1-Ay...
#
#                              Assigned Teaching Grads
# 0                                                  0
# 1  Esra Sinoplu (63770, BIO, 10 hours)\nYunus Akk...
# 2             Bahriye Karakas (63884, BIO, 20 hours)
# 3  Asma Abdullah Abdulwahab Al-murtadha (64036, B...
# 4              Burcu Alptekin (64100, BIO, 20 hours)

# %%
TA_df['CRN 1'] = TA_df['CRN 1'].astype('int64') # CRN values are actually integer values. However , they are float in the file
# Change the CRN 1 column value type to int as expected

# %%
TA_df['CRN 2'] = TA_df['CRN 2'].astype('int64')
#Change the CRN 2 column value type to int as expecte

# %%
TA_df['Name'] = TA_df['Name'].replace('\n','', regex=True)

# %%
TA_df['Assigned Course 2'] = TA_df['Assigned Course 2'].replace('\n','', regex=True)

# %%
TA_df.head()
# Out:
#    Student ID                         Name Degree Program  Hours Assigned  \
# 0       19928         Abba Ibrahim Ramadan     MS    MATH              20
# 1       18282  Abdolali Khalili Sadaghiani    PHD      ME              20
# 2       17061           Abdülkadir Canatar     MS    PHYS              20
# 3       19996              Abdullahi Adamu     MS      EE              10
# 4       14277            Abdurrahman Burak     MS      EE              10
#
#    Hours Requested                                  Requested Courses  \
# 0               20  1- MATH 101 (380 / 350)\n2- MATH 102 (130 / 17...
# 1               20                                                  0
# 2               20                                                  0
# 3               10  1- ENS 211 (60 / 75)\n2- MATH 203 (130 / 113)\...
# 4               10  1- EE 303 (30 / 15)\n2- EE 480 (0 / 5)\n3- ENS...
#
#   Assigned Course 1  CRN 1 Assigned Course 2  CRN 2
# 0          MATH 203  10401                 0      0
# 1          MATH 101  10536                 0      0
# 2            NS 101  10616                 0      0
# 3           ENS 211  10317                 0      0
# 4            EE 303  10923                 0      0

# %%
# Course dataframes turn
Course_df = Course_df.fillna(0) # replace all NaN values with 0

# %%
Course_df = Course_df.drop(Course_df.index[0])

# %%
Course_df['CRN'] = Course_df['CRN'].astype('int64')

# %%
Course_df['Hours Assigned'] = Course_df['Hours Assigned'].astype('int64')

# %%
Course_df['Hours Requested'] = Course_df['Hours Requested'].astype('int64')

# %%
Course_df.head()
# Out:
#      CRN     Name Section                       Title Preferred  \
# 1  10180  BIO 306       0                Microbiology         0
# 2  10182  BIO 321       0              Biochemistry I         0
# 3  10185  BIO 332       0                Cell Biology         0
# 4  11162  BIO 407       0  Multicellular Organization         0
# 5  10186  BIO 445       0  Plant Tissue Culture Tech.         0
#
#    Hours Assigned  Hours Requested  \
# 1              20               20
# 2              20               25
# 3              30               15
# 4              20               10
# 5              10               15
#
#                            Requesting Teaching Grads  \
# 1  1-Secil Erbil ( 64207 ) (10 / 10)\n1-Yunus Akk...
# 2  2-Secil Erbil ( 64207 ) (10 / 10)\n2-Yunus Akk...
# 3  1-Ersoy Colak ( 63844 ) (20 / 20)\n2-Ezgi Baki...
# 4  1-Tugce Ayca Tekiner ( 64138 ) (20 / 20)\n1-Ay...
# 5  1-Melike Cokol ( 64148 ) (10 / 10)\n2-Ersoy Co...
#
#                              Assigned Teaching Grads
# 1  Esra Sinoplu (63770, BIO, 10 hours)\nYunus Akk...
# 2             Bahriye Karakas (63884, BIO, 20 hours)
# 3  Asma Abdullah Abdulwahab Al-murtadha (64036, B...
# 4              Burcu Alptekin (64100, BIO, 20 hours)
# 5                Melike Cokol (64148, BIO, 10 hours)

# %% [markdown]
# ## How many TA's requested for each course ?

# %%
for courses in range(1,n_rows) :
    data = Course_df.at[courses,'Requesting Teaching Grads'].splitlines() 
    print(Course_df.at[courses,'Name'] , "requested" ,len(data),"TA's")
# Out:
# BIO 306 requested 3 TA's
# BIO 321 requested 5 TA's
# BIO 332 requested 5 TA's
# BIO 407 requested 5 TA's
# BIO 445 requested 5 TA's
# BIO 447 requested 5 TA's
# BIO 452 requested 7 TA's
# BIO 466 requested 4 TA's
# CHEM 301 requested 2 TA's
# CHEM 405 requested 5 TA's
# CHEM 421 requested 5 TA's
# CS 201 requested 25 TA's
# CS 204 requested 14 TA's
# CS 300 requested 8 TA's
# CS 302 requested 3 TA's
# CS 303 requested 8 TA's
# CS 307 requested 6 TA's
# CS 400 requested 1 TA's
# CS 402 requested 2 TA's
# CS 404 requested 5 TA's
# CS 405 requested 2 TA's
# CS 408 requested 3 TA's
# CS 411 requested 3 TA's
# CS 412 requested 3 TA's
# EE 303 requested 7 TA's
# EE 307 requested 3 TA's
# EE 311 requested 3 TA's
# EE 313 requested 2 TA's
# EE 401 requested 1 TA's
# EE 403 requested 1 TA's
# EE 407 requested 4 TA's
# EE 409 requested 4 TA's
# EE 413 requested 1 TA's
# EE 414 requested 1 TA's
# EE 417 requested 5 TA's
# EE 419 requested 5 TA's
# EE 444 requested 1 TA's
# EE 473 requested 5 TA's
# EE 480 requested 3 TA's
# ENS 202 requested 11 TA's
# ENS 203 requested 11 TA's
# ENS 205 requested 27 TA's
# ENS 207 requested 3 TA's
# ENS 208 requested 8 TA's
# ENS 209 requested 15 TA's
# ENS 211 requested 11 TA's
# ENS 315 requested 4 TA's
# ENS 413 requested 3 TA's
# ENS 480 requested 1 TA's
# ENS 491 requested 1 TA's
# IE 301 requested 13 TA's
# IE 302 requested 4 TA's
# IE 303 requested 14 TA's
# IE 304 requested 2 TA's
# IE 305 requested 5 TA's
# IE 309 requested 13 TA's
# IE 401 requested 9 TA's
# IE 402 requested 8 TA's
# IE 403 requested 3 TA's
# IE 405 requested 11 TA's
# IE 407 requested 2 TA's
# IE 408 requested 2 TA's
# IE 413 requested 3 TA's
# IE 414 requested 1 TA's
# IE 415 requested 2 TA's
# IE 430 requested 7 TA's
# IE 454 requested 2 TA's
# IE 480 requested 5 TA's
# IE 481 requested 3 TA's
# IE 482 requested 4 TA's
# IF 200 requested 4 TA's
# MAT 305 requested 4 TA's
# MAT 307 requested 6 TA's
# MAT 309 requested 1 TA's
# MAT 312 requested 10 TA's
# MAT 401 requested 4 TA's
# MAT 404 requested 4 TA's
# MAT 408 requested 10 TA's
# MAT 511 requested 10 TA's
# MATH 101 requested 79 TA's
# MATH 102 requested 35 TA's
# MATH 201 requested 27 TA's
# MATH 203 requested 20 TA's
# MATH 301 requested 3 TA's
# MATH 306 requested 6 TA's
# MATH 317 requested 6 TA's
# MATH 401 requested 2 TA's
# ME 301 requested 8 TA's
# ME 303 requested 5 TA's
# ME 307 requested 5 TA's
# ME 308 requested 7 TA's
# ME 312 requested 4 TA's
# ME 402 requested 3 TA's
# ME 407 requested 3 TA's
# ME 409 requested 2 TA's
# ME 420 requested 2 TA's
# ME 480 requested 1 TA's
# MJC 100 requested 2 TA's
# NS 101 requested 35 TA's
# NS 102 requested 27 TA's
# NS 201 requested 3 TA's
# NS 206 requested 4 TA's
# NS 207 requested 3 TA's
# NS 213 requested 2 TA's
# NS 222 requested 2 TA's
# PHD 100 requested 2 TA's
# PHYS 302 requested 2 TA's
# PHYS 303 requested 2 TA's
# PHYS 401 requested 2 TA's
# PHYS 412 requested 2 TA's
# PHYS 438 requested 1 TA's
# PROJ 102 requested 1 TA's
# SPS 315 requested 2 TA's
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-c41b7dae7998> in <module>
#       1
#       2 for courses in range(1,n_rows) :
# ----> 3     data = Course_df.at[courses,'Requesting Teaching Grads'].splitlines()
#       4     print(Course_df.at[courses,'Name'] , "requested" ,len(data),"TA's")
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2140
#    2141         key = self._convert_key(key)
# -> 2142         return self.obj._get_value(*key, takeable=self._takeable)
#    2143
#    2144     def __setitem__(self, key, value):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    2537
#    2538         try:
# -> 2539             return engine.get_value(series._values, index)
#    2540         except (TypeError, ValueError):
#    2541
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 114

# %%
for TA in range(1,109) :
    if Course_df.at[TA,'Assigned Teaching Grads'] != "None" :
        data = Course_df.at[TA,'Assigned Teaching Grads'].splitlines()
        print(Course_df.at[TA,'Name'] , "assigned" ,len(data),"TA's")
    else :
        print(Course_df.at[TA,'Name'] , "assigned" , 0,"TA's")
# Out:
# BIO 306 assigned 2 TA's
# BIO 321 assigned 1 TA's
# BIO 332 assigned 2 TA's
# BIO 407 assigned 1 TA's
# BIO 445 assigned 1 TA's
# BIO 447 assigned 1 TA's
# BIO 452 assigned 1 TA's
# BIO 466 assigned 1 TA's
# CHEM 301 assigned 2 TA's
# CHEM 405 assigned 0 TA's
# CHEM 421 assigned 0 TA's
# CS 201 assigned 12 TA's
# CS 204 assigned 4 TA's
# CS 300 assigned 2 TA's
# CS 302 assigned 1 TA's
# CS 303 assigned 6 TA's
# CS 307 assigned 1 TA's
# CS 400 assigned 1 TA's
# CS 402 assigned 1 TA's
# CS 404 assigned 1 TA's
# CS 405 assigned 2 TA's
# CS 408 assigned 2 TA's
# CS 411 assigned 2 TA's
# CS 412 assigned 1 TA's
# EE 303 assigned 3 TA's
# EE 307 assigned 1 TA's
# EE 311 assigned 1 TA's
# EE 313 assigned 1 TA's
# EE 401 assigned 1 TA's
# EE 403 assigned 0 TA's
# EE 407 assigned 1 TA's
# EE 409 assigned 1 TA's
# EE 413 assigned 0 TA's
# EE 414 assigned 0 TA's
# EE 417 assigned 3 TA's
# EE 419 assigned 0 TA's
# EE 444 assigned 0 TA's
# EE 473 assigned 1 TA's
# EE 480 assigned 0 TA's
# ENS 202 assigned 3 TA's
# ENS 203 assigned 5 TA's
# ENS 205 assigned 13 TA's
# ENS 207 assigned 1 TA's
# ENS 208 assigned 6 TA's
# ENS 209 assigned 8 TA's
# ENS 211 assigned 5 TA's
# ENS 315 assigned 2 TA's
# ENS 413 assigned 1 TA's
# ENS 480 assigned 1 TA's
# ENS 491 assigned 1 TA's
# IE 301 assigned 3 TA's
# IE 302 assigned 3 TA's
# IE 303 assigned 4 TA's
# IE 304 assigned 4 TA's
# IE 305 assigned 3 TA's
# IE 309 assigned 4 TA's
# IE 401 assigned 2 TA's
# IE 402 assigned 4 TA's
# IE 403 assigned 3 TA's
# IE 405 assigned 2 TA's
# IE 407 assigned 0 TA's
# IE 408 assigned 0 TA's
# IE 413 assigned 1 TA's
# IE 414 assigned 1 TA's
# IE 415 assigned 1 TA's
# IE 430 assigned 1 TA's
# IE 454 assigned 1 TA's
# IE 480 assigned 2 TA's
# IE 481 assigned 1 TA's
# IE 482 assigned 1 TA's
# IF 200 assigned 1 TA's
# MAT 305 assigned 1 TA's
# MAT 307 assigned 1 TA's
# MAT 309 assigned 1 TA's
# MAT 312 assigned 4 TA's
# MAT 401 assigned 1 TA's
# MAT 404 assigned 1 TA's
# MAT 408 assigned 1 TA's
# MAT 511 assigned 0 TA's
# MATH 101 assigned 24 TA's
# MATH 102 assigned 13 TA's
# MATH 201 assigned 10 TA's
# MATH 203 assigned 7 TA's
# MATH 301 assigned 1 TA's
# MATH 306 assigned 3 TA's
# MATH 317 assigned 0 TA's
# MATH 401 assigned 0 TA's
# ME 301 assigned 3 TA's
# ME 303 assigned 3 TA's
# ME 307 assigned 2 TA's
# ME 308 assigned 3 TA's
# ME 312 assigned 3 TA's
# ME 402 assigned 2 TA's
# ME 407 assigned 1 TA's
# ME 409 assigned 1 TA's
# ME 420 assigned 0 TA's
# ME 480 assigned 1 TA's
# MJC 100 assigned 3 TA's
# NS 101 assigned 28 TA's
# NS 102 assigned 16 TA's
# NS 201 assigned 2 TA's
# NS 206 assigned 1 TA's
# NS 207 assigned 3 TA's
# NS 213 assigned 1 TA's
# NS 222 assigned 1 TA's
# PHD 100 assigned 0 TA's
# PHYS 302 assigned 1 TA's
# PHYS 303 assigned 0 TA's

# %%
top_programs = TA_df['Program'].value_counts()
print(top_programs)
# Out:
# MAT     63
# IE      50
# ME      45
# EE      35
# CS      35
# BIO     32
# MATH    19
# PHYS    13
# Name: Program, dtype: int64

# %%
df = pd.DataFrame({'program':['MAT', 'IE', 'CS','ME','EE','BIO','MATH','PHYS'], 'val':[63, 50, 35,45,35,32,19,13]})
ax = df.plot.bar(x='program', y='val', rot=0)

plt.show()

# %%
matrix_df = pd.DataFrame(index=range(8),columns=range(109))
matrix_df = matrix_df.fillna(0)
#TA_df['CRN 2'] = TA_df['CRN 2'].astype('int64')

# %%
#now,lets try to fill it
matrix_df = matrix_df.rename(index={0:'MAT', 1: 'IE', 2 : 'CS', 3 : 'ME', 4 : 'EE', 5 : 'BIO' , 6 : 'MATH', 7 : 'PHYS'})

# %%
for i in range(1,114) :
    temp = Course_df.at[i,'Name']
    matrix_df=matrix_df.rename(columns = {i:temp})

# %%
Course_df.head()
# Out:
#      CRN     Name Section                       Title Preferred  \
# 1  10180  BIO 306       0                Microbiology         0
# 2  10182  BIO 321       0              Biochemistry I         0
# 3  10185  BIO 332       0                Cell Biology         0
# 4  11162  BIO 407       0  Multicellular Organization         0
# 5  10186  BIO 445       0  Plant Tissue Culture Tech.         0
#
#    Hours Assigned  Hours Requested  \
# 1              20               20
# 2              20               25
# 3              30               15
# 4              20               10
# 5              10               15
#
#                            Requesting Teaching Grads  \
# 1  1-Secil Erbil ( 64207 ) (10 / 10)\n1-Yunus Akk...
# 2  2-Secil Erbil ( 64207 ) (10 / 10)\n2-Yunus Akk...
# 3  1-Ersoy Colak ( 63844 ) (20 / 20)\n2-Ezgi Baki...
# 4  1-Tugce Ayca Tekiner ( 64138 ) (20 / 20)\n1-Ay...
# 5  1-Melike Cokol ( 64148 ) (10 / 10)\n2-Ersoy Co...
#
#                              Assigned Teaching Grads
# 1  Esra Sinoplu (63770, BIO, 10 hours)\nYunus Akk...
# 2             Bahriye Karakas (63884, BIO, 20 hours)
# 3  Asma Abdullah Abdulwahab Al-murtadha (64036, B...
# 4              Burcu Alptekin (64100, BIO, 20 hours)
# 5                Melike Cokol (64148, BIO, 10 hours)

# %%
# now fill NaN's
for i in range(8) :
    if i == 0 : # Mat
        for a in range(1,114) : # iterate through all courses
            temp_course = Course_df.at[a,'Name']
            temp_data = Course_df.at[a,'Assigned Teaching Grads'].split()
            for b in range(len(temp_data)) :
                if temp_data[b] == "MAT," :
                    matrix_df.at['MAT',temp_course] = matrix_df.at['MAT',temp_course] + 1
                    
    elif i == 1 : # IE
        for c in range(1,114) : # iterate through all courses
            temp_course = Course_df.at[c,'Name']
            temp_data = Course_df.at[c,'Assigned Teaching Grads'].split()
            for d in range(len(temp_data)) :
                if temp_data[d] == "IE," :
                    matrix_df.at['IE',temp_course] = matrix_df.at['IE',temp_course] + 1
                    
    elif i == 2 : # CS
        for e in range(1,114) : # iterate through all courses
            temp_course = Course_df.at[e,'Name']
            temp_data = Course_df.at[e,'Assigned Teaching Grads'].split()
            for f in range(len(temp_data)) :
                if temp_data[f] == "CS," :
                    matrix_df.at['CS',temp_course] = matrix_df.at['CS',temp_course] + 1
                    
    elif i == 3 : # ME
        for g in range(1,114) : # iterate through all courses
            temp_course = Course_df.at[g,'Name']
            temp_data = Course_df.at[g,'Assigned Teaching Grads'].split()
            for h in range(len(temp_data)) :
                if temp_data[h] == "ME," :
                    matrix_df.at['ME',temp_course] = matrix_df.at['ME',temp_course] + 1
                    
    elif i == 4 : # EE
        for j in range(1,114) : # iterate through all courses
            temp_course = Course_df.at[j,'Name']
            temp_data = Course_df.at[j,'Assigned Teaching Grads'].split()
            for k in range(len(temp_data)) :
                if temp_data[k] == "EE," :
                    matrix_df.at['EE',temp_course] = matrix_df.at['EE',temp_course] + 1
                            
    elif i == 5 : # BIO
        for l in range(1,114) : # iterate through all courses
            temp_course = Course_df.at[l,'Name']
            temp_data = Course_df.at[l,'Assigned Teaching Grads'].split()
            for m in range(len(temp_data)) :
                if temp_data[m] == "BIO," :
                    matrix_df.at['BIO',temp_course] = matrix_df.at['BIO',temp_course] + 1
                            
    elif i == 6 : # MATH
        for n in range(1,114) : # iterate through all courses
            temp_course = Course_df.at[n,'Name']
            temp_data = Course_df.at[n,'Assigned Teaching Grads'].split()
            for o in range(len(temp_data)) :
                if temp_data[o] == "MATH," :
                    matrix_df.at['MATH',temp_course] = matrix_df.at['MATH',temp_course] + 1
                    
    elif i == 7 : # PHYS
        for p in range(1,114) : # iterate through all courses
            temp_course = Course_df.at[p,'Name']
            temp_data = Course_df.at[p,'Assigned Teaching Grads'].split()
            for r in range(len(temp_data)) :
                if temp_data[r] == "PHYS," :
                    matrix_df.at['PHYS',temp_course] = matrix_df.at['PHYS',temp_course] + 1
        
    
                        
            
            
            
            #### drop proj 102
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PROJ 102'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-15641b285f02> in <module>
#       7             for b in range(len(temp_data)) :
#       8                 if temp_data[b] == "MAT," :
# ----> 9                     matrix_df.at['MAT',temp_course] = matrix_df.at['MAT',temp_course] + 1
#      10
#      11     elif i == 1 : # IE
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2140
#    2141         key = self._convert_key(key)
# -> 2142         return self.obj._get_value(*key, takeable=self._takeable)
#    2143
#    2144     def __setitem__(self, key, value):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    2533             return com._maybe_box_datetimelike(series._values[index])
#    2534
# -> 2535         series = self._get_item_cache(col)
#    2536         engine = self.index._engine
#    2537
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PROJ 102'
